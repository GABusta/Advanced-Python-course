# %% [markdown]
# <a href="https://colab.research.google.com/github/GABusta/Advanced-Python-course/blob/main/Regresion_con_Scikit_Learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Regresión Lineal en Python**
#
# **paquete scikit-learn para regresión lineal y la selección de rasgos**

# %%
from sklearn.feature_selection import RFE
from sklearn.svm import SVR
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Advertising.csv')

# %%
feature_cols = ['TV', 'Radio', 'Newspaper']  # columnas de predicción

# %%
X = data[feature_cols]
Y = data['Sales']       # variable a ser predecida

# %%
estimator = SVR(kernel='linear')
selector = RFE(estimator, n_features_to_select=2, step=1)  # quiero 2 variables predictivas
selector = selector.fit(X, Y)

# %%
selector.support_
# Out:
# array([ True,  True, False])

# %% [markdown]
# automaticamente me dice que las primeras dos variables son las más importantes en la regresión

# %% [markdown]
# Regresión automática con sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
X_pred = X[['TV', 'Radio']]  # variables predictoras

# %%
lm = LinearRegression()
lm.fit(X_pred, Y)
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# 2.921099912405138

# %%
lm.coef_
# Out:
# array([0.04575482, 0.18799423])
